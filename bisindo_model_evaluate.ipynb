# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("agungmrf/indonesian-sign-language-bisindo")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.36G/1.36G [00:23<00:00, 62.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/agungmrf/indonesian-sign-language-bisindo/versions/1

# %%
train_dir = '/root/.cache/kagglehub/datasets/agungmrf/indonesian-sign-language-bisindo/versions/1/bisindo/images/train'

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

model = load_model('/content/my_model.h5')

# Function to preprocess image and predict class
def classify_image(img_path):
    img = image.load_img(img_path, target_size=(100, 100))

    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array.astype('float32') / 255.0

    # Predict the class
    prediction = model.predict(img_array)

    predicted_class_idx = np.argmax(prediction[0])
    class_labels = sorted(os.listdir(train_dir))
    predicted_class_label = class_labels[predicted_class_idx]

    # Print and display the result
    print(f"Predicted class: {predicted_class_label} (Index: {predicted_class_idx})")

    # Show the image
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.title(f"Predicted: {predicted_class_label}")
    plt.axis('off')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
img_path = '/content/C.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# Predicted class: S (Index: 18)

# %%
img_path = '/content/C1.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted class: C (Index: 2)

# %%
img_path = '/content/D.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Predicted class: D (Index: 3)

# %%
img_path = '/content/E1.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Predicted class: E (Index: 4)

# %%
img_path = '/content/F.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted class: F (Index: 5)

# %%
img_path = '/content/F1.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted class: S (Index: 18)

# %%
img_path = '/content/G.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted class: G (Index: 6)

# %%
img_path = '/content/G1.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted class: G (Index: 6)

# %%
img_path = '/content/H.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted class: H (Index: 7)

# %%
img_path = '/content/I.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted class: I (Index: 8)

# %%
img_path = '/content/O.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted class: O (Index: 14)

# %%
img_path = '/content/S.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted class: S (Index: 18)

# %%
img_path = '/content/V.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted class: V (Index: 21)

# %%
img_path = '/content/Z.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted class: Z (Index: 25)

# %%
img_path = '/content/ALPHA C2.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted class: O (Index: 14)

# %%
img_path = '/content/WIN_20241203_03_26_01_Pro.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted class: Z (Index: 25)

# %%
img_path = '/content/WIN_20241203_03_26_32_Pro.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted class: Z (Index: 25)
