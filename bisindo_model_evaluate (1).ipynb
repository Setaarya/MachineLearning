# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("agungmrf/indonesian-sign-language-bisindo")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.36G/1.36G [00:19<00:00, 75.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/agungmrf/indonesian-sign-language-bisindo/versions/1

# %%
train_dir = '/root/.cache/kagglehub/datasets/agungmrf/indonesian-sign-language-bisindo/versions/1/bisindo/images/train'

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

model = load_model('/content/my_model.h5')

# Function to preprocess image and predict class
def classify_image(img_path):
    img = image.load_img(img_path, target_size=(100, 100))

    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array.astype('float32') / 255.0

    # Predict the class
    prediction = model.predict(img_array)

    predicted_class_idx = np.argmax(prediction[0])
    class_labels = sorted(os.listdir(train_dir))
    predicted_class_label = class_labels[predicted_class_idx]

    # Print and display the result
    print(f"Predicted class: {predicted_class_label} (Index: {predicted_class_idx})")

    # Show the image
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.title(f"Predicted: {predicted_class_label}")
    plt.axis('off')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
img_path = '/content/WhatsApp Image 2024-12-10 at 21.11.52_62876d9c.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Predicted class: S (Index: 18)

# %%
img_path = '/content/WhatsApp Image 2024-12-10 at 21.11.52_eaf518fd.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted class: A (Index: 0)

# %%
img_path = '/content/WhatsApp Image 2024-12-10 at 21.18.37_470a73fd.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Predicted class: W (Index: 22)

# %%
img_path = '/content/WhatsApp Image 2024-12-10 at 21.18.38_52797ff1.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted class: C (Index: 2)

# %%
img_path = '/content/WhatsApp Image 2024-12-10 at 21.18.38_a013e466.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted class: A (Index: 0)

# %%
img_path = '/content/WhatsApp Image 2024-12-10 at 21.18.38_aa958d28.jpg'
classify_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted class: U (Index: 20)
